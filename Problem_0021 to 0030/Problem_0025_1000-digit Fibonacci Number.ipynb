# %%
fn_2 = 1
fn_1 = 1
fn = 2
n = 3

# %%
while len(str(fn)) < 1000:
    n += 1
    fn_2 = fn_1
    fn_1 = fn
    fn = fn_2 + fn_1

# %%
fn
# Out:
# ...

# %%
n
# Out:
# 4782

# %% [markdown]
# ## Nth element of fibonacci can be found this way
#
# ### useless for this problem!

# %%
from sympy.functions.combinatorial.numbers import fibonacci as fib

# %%
fib(4782)
# Out:
# ...
