# %%
number_string = \
"73167176531330624919225119674426574742355349194934\
96983520312774506326239578318016984801869478851843\
85861560789112949495459501737958331952853208805511\
12540698747158523863050715693290963295227443043557\
66896648950445244523161731856403098711121722383113\
62229893423380308135336276614282806444486645238749\
30358907296290491560440772390713810515859307960866\
70172427121883998797908792274921901699720888093776\
65727333001053367881220235421809751254540594752243\
52584907711670556013604839586446706324415722155397\
53697817977846174064955149290862569321978468622482\
83972241375657056057490261407972968652414535100474\
82166370484403199890008895243450658541227588666881\
16427171479924442928230863465674813919123162824586\
17866458359124566529476545682848912883142607690042\
24219022671055626321111109370544217506941658960408\
07198403850962455444362981230987879927244284909188\
84580156166097919133875499200524063689912560717606\
05886116467109405077541002256983155200055935729725\
71636269561882670428252483600823257530420752963450"

# %%
import numpy as np
from math import prod

# %%
largest_13digit = 0
largest_prod = 0

# %%
for i in range(len(number_string)-13):
    next_number = number_string[i:i+13]
    if(min(next_number) == '0'): continue
    next_prod = prod(list(map(int,next_number)))
    print(i,next_number, next_prod)
    if next_prod > largest_prod:
        largest_13digit = next_number
        largest_prod = next_prod
        print("------>",largest_13digit, largest_prod)
# Out:
# 0 7316717653133 5000940
# ------> 7316717653133 5000940
# 14 6249192251196 4199040
# 15 2491922511967 4898880
# 16 4919225119674 9797760
# ------> 4919225119674 9797760
# 17 9192251196744 9797760
# 18 1922511967442 2177280
# 19 9225119674426 13063680
# ------> 9225119674426 13063680
# 20 2251196744265 7257600
# 21 2511967442657 25401600
# ------> 2511967442657 25401600
# 22 5119674426574 50803200
# ------> 5119674426574 50803200
# 23 1196744265747 71124480
# ------> 1196744265747 71124480
# 24 1967442657474 284497920
# ------> 1967442657474 284497920
# 25 9674426574742 568995840
# ------> 9674426574742 568995840
# 26 6744265747423 189665280
# 27 7442657474235 158054400
# 28 4426574742355 112896000
# 29 4265747423553 84672000
# 30 2657474235534 84672000
# 31 6574742355349 381024000
# 32 5747423553491 63504000
# 33 7474235534919 114307200
# 34 4742355349194 65318400
# 35 7423553491949 146966400
# 36 4235534919493 62985600
# 37 2355349194934 62985600
# 38 3553491949349 283435200
# ...

# %%
largest_13digit, largest_prod
# Out:
# ('5576689664895', 23514624000)
